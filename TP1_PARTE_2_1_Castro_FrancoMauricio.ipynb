# %% [markdown]
# <a href="https://colab.research.google.com/github/MauricioCastroF/VC1_EntregaTP/blob/main/TP1_PARTE_2_1_Castro_FrancoMauricio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/FIUBA-Posgrado-Inteligencia-Artificial/vision_computadora_I.git
# !cd vision_computadora_I && git checkout 8va-cohorte
# Out:
# Cloning into 'vision_computadora_I'...
# remote: Enumerating objects: 523, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 523 (delta 7), reused 32 (delta 7), pack-reused 488
# Receiving objects: 100% (523/523), 156.95 MiB | 16.37 MiB/s, done.
# Resolving deltas: 100% (161/161), done.
# Branch '8va-cohorte' set up to track remote branch '8va-cohorte' from 'origin'.
# Switched to a new branch '8va-cohorte'

# %%
# %matplotlib inline  
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
cd vision_computadora_I/Material_TPs/TP1
# Out:
# /content/vision_computadora_I/Material_TPs/TP1

# %%
img1 = cv.imread('img1_tp.png', cv.IMREAD_GRAYSCALE);img2 = cv.imread('img2_tp.png', cv.IMREAD_GRAYSCALE)

fig, axs = plt.subplots(1, 2, figsize=(12,8))
fig.suptitle('Imágenes en escala de grises')
fig.tight_layout() 

axs[0].imshow(img1, cmap='gray', vmin=0, vmax=255);axs[1].imshow(img2, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# Se eligieron 25 binds, debido a que determina de manera adecuada la forma de la distribución de los valores.

# %%
#histograma para la imagen 1
histograma, bins = np.histogram(img1, bins=25, range=(0, 255))
plt.figure()
plt.title("Histograma de escala de grises")
plt.xlabel("Valor")
plt.ylabel("Cantidad de píxeles")
plt.xlim([0.0, 256])
plt.plot(bins[0:-1], histograma)

# %%
#histograma para la imagen 2
histograma, bins = np.histogram(img2, bins=25, range=(0, 255))
plt.figure()
plt.title("Histograma de escala de grises")
plt.xlabel("Valor")
plt.ylabel("Cantidad de píxeles")
plt.xlim([0.0, 256])
plt.plot(bins[0:-1], histograma)

# %% [markdown]
# En ambas imágenes, se observa: i)patrones similares de distribución y ii) las imágenes no están preprocesadas.
#
# En general, se observa una trimodalidad. La primera es en el rango de valores entre 25-50; la segunda entre 175-225 y la tercera en 255. Es decir, baja cantidad de sombras, cantidad considerable de tonos medio bajos y medio altos, y cantidad considerable de tonos altos (blancos).
#
# Dispongo de dos imágenes diferentes con la misma distribución de frecuencia. Si tuviera que entrenar un modelos de clasificación, las opciones podrían ser: i) identificar los objetos que de acuerdo a segmentos de la distribución por imagen, para luego aplicar la clasificación; o ii) ejecutar un aumento de contraste que modifique el histograma y me facilite la segmentación de rangos de valores, con su relación de objeto correspondiente.
